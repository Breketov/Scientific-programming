# %%
# 1
a, b = map(int, input().split())
print(a + b)

# 108
a = input()
print(a)

# 195
a, b, c = map(int, input().split())
print(a*b*c*2)

# 903
a = int(input())
print(a + 1)

# 3
a = list(input())
if len(a) == 1:
    print('25')
else:
    a = a[0:-1]
    b = ''
    for i in a:
        b +=i
    b = int(b)
    print(str(b*(b + 1)) + '25')

# %%
# 25
a = int(input())
b = int(input())
if a < b:
    print('<')
elif a > b:
    print('>')
else:
    print('=')

# 8
a, b, c = map(int, input().split())
if a*b == c:
    print('YES')
else:
    print('NO')

# 907
a, b, c = map(int, input().split())
if a >= c*2 and b >= c*2:
    print('YES')
else:
    print('NO')

# 539
a = int(input())
if a > 1:
    if a % 2 == 0:
    	print(f'{int(a/2)}')
    else:
        print(f'{a}')
else:
    print('0')

# 92
a = int(input())
x = a//6
print(x, 4*x, x)

# 597
a, b, c = map(int, input().split())
if a >= b + c:
    print('YES')
else:
    print('NO')

# %%
# 68
location = input()
x = int(input())
if (x % 2 == 1) or (location == 'Home'):
    output_string = 'Yes'
else:
    output_string = 'No'
print(output_string)

# 106
a = int(input())
b = []
for i in range(0, a):
    b.append(int(input()))
c = sum(b)
if c <= a//2:
    print(c)
else:
    print(a - c)

# 43
a = list(input())
b = 0
c = []
for i in a:
    if i == '0':
        b += 1
    else:
        c.append(b)
        b = 0
c.append(b)
print(max(c))

# 81
a = int(input())
b = list(map(int, input().split()))
print(min(b), max(b))

# %%
# 409
n = int(input())
points = list(map(int, input().split()))
total_sum = 0
for i in range(n - 1):
    total_sum += points[i] + (points[i + 1] - points[i]) / 2
total_sum /= (n - 1)
print(total_sum)

# 322
s = list(input())
t1 = 0
t2 = 1
while t1 + t2 <= len(s):
    t3 = t1 + t2
    print(s[t3 - 1], end = '')
    t1 = t2
    t2 = t3

# 44
s = input()
j = 0
for i in range(0, len(s) - 4):
    t = s[i : i + 5]
    if t == '>>-->' or t == '<--<<':
        j += 1
print(j)

# 65
def hemming(s1, s2):
    j = 0
    for i in range(len(s1)):
        if s1[i] != s2[i]:
            j += 1
    return j
s = input()
n = int(input())
v = []
min_s = len(s) + 1
for i in range(n):
    m = input()
    h = hemming(s, m)
    if h == min_s:
        v.append(i + 1)
    if h < min_s:
        min_s = h
        v = []
        v.append(i + 1)
print(len(v))
print(*v)

# 712
w, h, n = map(int, input().split())
left, right = 0, max(w, h) * n
while left < right:
    mid = (left + right) // 2
    if (mid // w) * (mid // h) >= n:
        right = mid
    else:
        left = mid + 1
print(left)
# Out:
# 2.0
